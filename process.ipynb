# %%
# prepare data
from mint_plus.data.prepare_alt2 import prepare_data_stream_optimized

prepare_data_stream_optimized(
    sequences_file = "./data/raw/protein.sequences.v12.0.fa",
    clusters_file = "./data/raw/linclu40.tsv",  # mmseqs linclust with default params
    links_file = "./data/raw/protein.physical.links.v12.0.txt.gz",
    output_dir = "./data",
    val_size = 250_000,
)  # original paper has 382 million PPIs with 29 million unique sequences, now i kept 635 million PPIs after clustering, different
# Out:
# 2026-06-02 17:02:56 - mint_plus.data.prepare_alt2 - INFO - === Reading Cluster Representatives ====
# 59309604it [01:17, 768229.44it/s]
# 2026-06-02 17:05:35 - mint_plus.data.prepare_alt2 - INFO - === Simulating Shuffle 1 ====
# 2026-06-02 17:07:14 - mint_plus.data.prepare_alt2 - INFO - === Mapping link tokens to memory-efficient IDs ====
# Mapping tokens: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 2365172266/2365172266 [39:32<00:00, 996934.53it/s]
# 2026-06-02 17:46:46 - mint_plus.data.prepare_alt2 - INFO - Shuffling layout arrays...
# 2026-06-02 17:47:58 - mint_plus.data.prepare_alt2 - INFO - === Filtering Unique Cluster Links (Numba Parallel) ====
# 2026-06-02 17:48:04 - mint_plus.data.prepare_alt2 - INFO - Getting and sorting unique indices...
# 2026-06-02 18:01:32 - mint_plus.data.prepare_alt2 - INFO - Kept 635398166 / 2365172266 links.
# 2026-06-02 18:01:32 - mint_plus.data.prepare_alt2 - INFO - === Simulating Shuffle 2 ====
# 2026-06-02 18:01:56 - mint_plus.data.prepare_alt2 - INFO - Identifying validation clusters...
# 2026-06-02 18:01:56 - mint_plus.data.prepare_alt2 - INFO - Building filtered training mask (Numba Parallel)...
# 2026-06-02 18:02:03 - mint_plus.data.prepare_alt2 - INFO - Building boolean target masks for O(1) streaming pass...
# 2026-06-02 18:02:09 - mint_plus.data.prepare_alt2 - INFO - === High-Speed FASTA Indexing ====
# 358074789it [03:51, 1547846.51it/s]
# 2026-06-02 18:06:00 - mint_plus.data.prepare_alt2 - INFO - === Final Pass: Streaming exact matching files to disk ====
# Streaming outputs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 2365172266/2365172266 [43:05<00:00, 914662.76it/s]
# 2026-06-02 18:49:06 - mint_plus.data.prepare_alt2 - INFO - Finished! Massive memory drop and maximum speed execution complete.

# %%
from scripts.prepare_data import prepare_data_stream_optimized

prepare_data_stream_optimized(
    sequences_file = "./data/raw/protein.sequences.v12.0.fa",
    clusters_file = "./data/raw/diamond_clust50.tsv",  # diamond cluster seq.fa approx-id 50, 12_707_913 clusters
    links_file = "./data/raw/protein.physical.links.v12.0.txt.gz",
    output_dir = "./data/diamond",
    val_size = 100_000,
) # 123738108 training links
# Out:
# 2026-06-11 11:01:35 - scripts.prepare_data - INFO - === Reading Cluster Representatives ====
# 59309604it [01:13, 808914.75it/s]
# 2026-06-11 11:03:54 - scripts.prepare_data - INFO - === Simulating Shuffle 1 ====
# 2026-06-11 11:06:11 - scripts.prepare_data - INFO - === Mapping link tokens to memory-efficient IDs ====
# Mapping tokens: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 2365172266/2365172266 [37:08<00:00, 1061212.30it/s]
# 2026-06-11 11:44:54 - scripts.prepare_data - INFO - === Filtering Unique Cluster Links (Numba Parallel) ====
# 2026-06-11 12:01:51 - scripts.prepare_data - INFO - Kept 340160910 / 2365172266 links.
# 2026-06-11 12:01:51 - scripts.prepare_data - INFO - === Simulating Shuffle 2 ====
# 2026-06-11 12:02:15 - scripts.prepare_data - INFO - === High-Speed FASTA Indexing ====
# 358074789it [04:16, 1396960.49it/s]
# 2026-06-11 12:06:32 - scripts.prepare_data - INFO - === Final Pass: Streaming exact matching files to disk ====
# Streaming outputs: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 2365172266/2365172266 [34:06<00:00, 1155754.26it/s]
# 2026-06-11 12:40:38 - scripts.prepare_data - INFO - Finished! 123738108 training links!

# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '1,2'

from mint_plus.trainer import MINTTrainer
trainer = MINTTrainer.from_config("configs/recipes/frozen_8M.yaml")
trainer.fit()
# Out:
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO - Interactive notebook detected. Using strategy: ddp_notebook_find_unused_parameters_true
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO - Starting training...
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Model size: 8M
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Use multimer: True
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Freeze self-attn: True
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Batch size: 4
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Accumulate grad: 16
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Max steps: 40001
# 2026-06-08 11:42:56 - mint_plus.trainer - INFO -   Strategy: ddp_notebook_find_unused_parameters_true
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /mnt/data/wee/mint_plus/ckpts/8M_frozen exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1,2]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [1,2]
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#   | Name  | Type | Params | Mode  | FLOPs
# -----------------------------------------------
# 0 | model | ESM2 | 9.4 M  | train | 0
# -----------------------------------------------
# 1.8 M     Trainable params
# 7.5 M     Non-trainable params
# 9.4 M     Total params
# 37.445    Total estimated model params size (MB)
# 97        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |                                                                | 0/? [00:00<?, ?it/s]
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/lightning/pytorch/utilities/data.py:123: Your `IterableDataset` has `__len__` defined. In combination with multi-process data loading (when num_workers > 1), `__len__` could be inaccurate if each worker is not configured independently to avoid having duplicate data.
# 2026-06-08 11:42:58 - mint_plus.wrapper - INFO - {'val_tokens': 370.0, 'val_loss': 36.6689567565918, 'val_perplexity': 8460831364743168.0, 'val_dur': 0.9045270681381226, 'entries': 4, 'epoch': 0, 'step': 0, 'iter_step': 1}
# Training: |                                                                       | 0/? [00:00<?, ?it/s]
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/torch/autograd/graph.py:869: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/torch/autograd/graph.py:869: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /mnt/data/wee/miniconda/envs/neu/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3675: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# prepare data
from mint_plus.data.prepare_alt import prepare_data_stream_optimized

prepare_data_stream_optimized(
    sequences_file = "./data/raw/protein.sequences.v12.0.fa", 
    clusters_file = "./data/raw/linclu50.tsv",  # mmseqs linclust with default params
    links_file = "./data/raw/protein.physical.links.v12.0.txt.gz",
    output_dir = "./data",
    val_size = 250_000,
)  # total count is 2_365_172_266, 358074789 sequences,
# Out:
# 2026-06-02 15:58:53 - mint_plus.data.prepare_alt - INFO - === Reading Cluster Representatives ====
# 59309604it [01:12, 815228.12it/s]
# 2026-06-02 16:01:19 - mint_plus.data.prepare_alt - INFO - === Simulating Shuffle 1 ====
# 2026-06-02 16:03:08 - mint_plus.data.prepare_alt - INFO - === Mapping link tokens to memory-efficient IDs ====
# Mapping tokens: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 2365172266/2365172266 [42:03<00:00, 937108.02it/s]
# 2026-06-02 16:45:12 - mint_plus.data.prepare_alt - INFO - Shuffling...
# 2026-06-02 16:52:36 - mint_plus.data.prepare_alt - INFO - === Filtering Unique Cluster Links ====
